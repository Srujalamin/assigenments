# %% [markdown]
# 1. write the python program to cheak if a number is positive,negative or zero.

# %% [markdown]
# # New Section

# %%
num =float(input('enter a number'))
if num ==0:
  print('zero')
elif num>=0:   
  print('positive number')  
else:
  print('negative number')
# Out:
# enter a number636
# positive number

# %% [markdown]
# 2.
# Write a Python program to get the Factorial number of given number.

# %%
n = 3
fact = 1

for i in range(1,n+1):
  fact = fact * i

  print("The factorial of 3 is : " ,end=" ")
  print(fact)
# Out:
# The factorial of 3 is :  1
# The factorial of 3 is :  2
# The factorial of 3 is :  6

# %%
num = 6
factorial =1

if num < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1,num + 1):
       factorial = factorial*i
   print("The factorial of",num,"is",factorial)
# Out:
# The factorial of 6 is 720

# %% [markdown]
# 3.
# Write a Python program to get the Fibonacci series of given range.

# %%
def Fibonacci(n):
  if n<0 :
    print("incorrct input")
  
  elif n==0:
    return 0
  elif n==1 or n==2:
    return 1
  else:
    return Fibonacci(n-1) + Fibonacci(n-2)
  print(Fibonacci(9))

# %%
def Fibonacci(n):
  a=0
  b=1

  if n <0:
    print("incorrct input")
  elif n==0:
    return 0
  elif n==1:
    return b
  else:
    for i in range(1,n):
      c=a+b
      a=b
      b=c
  return b
  print(Fibonacci(9))

# %% [markdown]
# 4.How memory is managed in Python?

# %% [markdown]
# *The Python memory is primarily managed by Python private heap space.
# *All Python objects and data structures are located in a private heap.
# *The programmer does not have access to this private heap and interpreter takes care of this Python private heap.

# %% [markdown]
# 5.What is the purpose continue statement in python?

# %% [markdown]
# The continue statement in Python returns the control to the beginning of the while loop

# %% [markdown]
# 6.Write python program that swap two number with temp variable and without temp variable.

# %%
x = 5
y = 1

x = input('Enter value of x: ')
y = input('Enter value of y: ')


temp = x
x = y
y = temp

print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Out:
# Enter value of x: 1
# Enter value of y: 5
# The value of x after swapping: 5
# The value of y after swapping: 1

# %% [markdown]
# 7.Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user.

# %%
num= int(input("enter a nuber: "))
aks= num%2
if aks > 0:
  print ("youe entre nuber is odd")
else:
  print("your enter numer is even")
# Out:
# enter a nuber: 35
# youe entre nuber is odd

# %% [markdown]
# 8. Write a Python program to test whether a passed letter is a vowel or not.

# %%
i =['a','k','i','r','u','A','o','l']
a= input ("enter the leter :")
if a in i:
  print("letter is vowel")
else:
    print("letter is not vowel")
# Out:
# enter the leter :s
# letter is not vowel

# %% [markdown]
# 9.Write a Python program to sum of three given integers. However, if two values are equal sum will be zero.

# %%
def sum_three(x, y, z):
    if x == y or y == z or x==z:
        sum = 0
    else:
        sum = x + y + z
    return sum
print(sum_three(2, 1, 2))
print(sum_three(3, 2, 2))
print(sum_three(2, 2, 2))
print(sum_three(1, 2, 3))
# Out:
# 0
# 0
# 0
# 6

# %% [markdown]
# 10. Write a Python program that will return true if the two given integer values are equal or their sum or difference is 5.

# %%
def test_number5(x, y):
   if x == y or abs(x-y) == 5 or (x+y) == 5:
       return True
   else:
       return False
print(test_number5(7, 2))
print(test_number5(3, 2))
print(test_number5(7, 3))
print(test_number5(27, 53))
# Out:
# True
# True
# False
# False

# %% [markdown]
# 11.Write a python program to sum of the first n positive integers

# %%
n = int(input("Input a number: "))
sum_num = (n * (n + 1)) // 2
print("Sum of the first", n ,"positive integers:", sum_num)
# Out:
# Input a number: 11
# Sum of the first 11 positive integers: 66

# %% [markdown]
# 12.Write a Python program to calculate the length of a string.

# %%
str = input("Enter a string: ")
count = 0
for s in str:
      count = count+1
print("Length of the input string is:", count)
# Out:
# Enter a string: srujal amin
# Length of the input string is: 11

# %% [markdown]
# 13.Write a Python program to count the number of characters (character frequency) in a string

# %%
def char_frequency(str):
    dict = {}
    for s in str:
        keys = dict.keys()
        if s in keys:
            dict[s] += 1
        else:
            dict[s] = 1
    return dict
print(char_frequency('srujal amin'))
# Out:
# {'s': 1, 'r': 1, 'u': 1, 'j': 1, 'a': 2, 'l': 1, ' ': 1, 'm': 1, 'i': 1, 'n': 1}

# %% [markdown]
# 14.What are negative indexes and why are they used?

# %% [markdown]
# The negative index is used to remove any new-line spaces from the string and allow the string to except the last character that is given as S[:-1]

# %% [markdown]
# 15.Write a Python program to count occurrences of a substring in a string.

# %%
str = 'srujal amin .'
print()
print(str.count("amin"))
print()
# Out:
# 1

# %% [markdown]
# 16.Write a Python program to count the occurrences of each word in a given sentence

# %%
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

print( word_count('srujal amin srujal'))
# Out:
# {'srujal': 2, 'amin': 1}

# %% [markdown]
# 17. Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.

# %%
def chars_mix_up(a, b):
  new_a = b[:2] + a[2:]
  new_b = a[:2] + b[2:]

  return new_a +' '+ new_b
print(chars_mix_up('sam', 'kys'))
# Out:
# kym sas

# %% [markdown]
# 18. Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing' then add 'ly' instead if the string length of the given string is less than 3, leave it unchanged.

# %%
def add_string(str):
  length = len(str)

  if length > 2:
    if str[-3:] == 'ing':
      str += 'ly'
    else:
      str += 'ing'

  return str
print(add_string('ri'))
print(add_string('rin'))
print(add_string('string'))
# Out:
# ri
# rining
# stringly

# %% [markdown]
# 19.Write a Python program to find the first appearance of the substring 'not' and 'poor' from a given string, if 'not' follows the 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string.

# %%
def not_poor(str):
  snot = str.find('not')
  spoor = str.find('poor')
  

  if spoor > snot and snot>0 and spoor>0:
    str = str.replace(str[snot:(spoor+4)], 'good')
    return str
  else:
    return str
print(not_poor('The lyrics is not that poor!'))
print(not_poor('The lyrics is poor!'))
# Out:
# The lyrics is good!
# The lyrics is poor!

# %% [markdown]
# 20.Write a Python function that takes a list of words and returns the length of the longest one.

# %%
def find_longest_word(words_list):
    word_len = []
    for n in words_list:
        word_len.append((len(n), n))
    word_len.sort()
    return word_len[-1][0], word_len[-1][1]
result = find_longest_word(["amin", "srujal", "Badshah"])
print("\nLongest word: ",result[1])
print("Length of the longest word: ",result[0])
# Out:
# Longest word:  Badshah
# Length of the longest word:  7

# %% [markdown]
# 21.Write a Python function to reverses a string if its length is a multiple of 4

# %%
def reverse_string(str):
    if len(str) % 4 == 0:
       return ''.join(reversed(str))
    return str

print(reverse_string('kiru'))
print(reverse_string('srujal'))
# Out:
# urik
# srujal

# %% [markdown]
# 22.Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. If the string length is less than 2, return instead of the empty string.
#  o Sample String: w3resource'
#  o Expected Result: 'w3ce'
#  o Sample String: 'w3'
#  o Expected Result: 'w3w3'
#  o Sample String: ' w'
#  o Expected Result: Empty String

# %%
def string_both_ends(str):
  if len(str) < 2:
    return ''

  return str[0:2] + str[-2:]

print(string_both_ends('w3resource'))
print(string_both_ends('w3'))
print(string_both_ends('w'))
# Out:
# w3ce
# w3w3

# %% [markdown]
# 23.  Write a Python function to insert a string in the middle of a string.

# %%
str = 'Hello, my name is amin.'
index = str.find('amin')
last_str = str[:index] + 'srujal ' + str[index:]
print(last_str)
# Out:
# Hello, my name is srujal amin.
